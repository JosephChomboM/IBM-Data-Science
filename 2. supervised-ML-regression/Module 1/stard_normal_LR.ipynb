# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '../Data/dataset_regresion.csv'
df = pd.read_csv(path)
df
# Out:
#      edad_inm     dist_est  nro_tiendas   latitud   longitud  precio_m2_1K
# 0        32.0  2186.834670           10  24.98298  121.54024          37.9
# 1        19.5   822.880872            9  24.98034  121.53951          42.2
# 2        13.3   561.984500            5  24.98746  121.54391          47.3
# 3        13.3   561.984500            5  24.98746  121.54391          54.8
# 4         5.0  1667.026714            5  24.97937  121.54245          43.1
# ..        ...          ...          ...       ...        ...           ...
# 409      13.7  2725.684379            0  24.94155  121.50381          15.4
# 410       5.6  1513.811048            9  24.97433  121.54310          50.0
# 411      18.8  1922.792529            7  24.97923  121.53986          40.6
# 412       8.1  1052.074479            5  24.96674  121.54067          52.5
# 413       6.5  2369.305970            9  24.97433  121.54310          63.9
#
# [414 rows x 6 columns]

# %%
df.describe().T
# Out:
#               count         mean         std        min         25%  \
# edad_inm      414.0    17.712560   11.392485    0.00000    9.025000
# dist_est      414.0  1607.034799  725.348526  506.11440  995.755400
# nro_tiendas   414.0     4.094203    2.945562    0.00000    1.000000
# latitud       414.0    24.969030    0.012410   24.93207   24.963000
# longitud      414.0   121.533361    0.015347  121.47353  121.528085
# precio_m2_1K  414.0    37.790979   13.030469    7.60000   27.700000
#
#                       50%          75%          max
# edad_inm        16.100000    28.150000    43.800000
# dist_est      1522.528226  2192.108592  2989.046544
# nro_tiendas      4.000000     6.000000    10.000000
# latitud         24.971100    24.977455    25.014590
# longitud       121.538630   121.543305   121.566270
# precio_m2_1K    38.450000    46.550000    78.300000

# %%
for col in df.columns:
    plt.figure()
    sns.histplot(df[col])

# %%
y_col = 'precio_m2_1K'
X = df.drop(y_col, axis=1)
y = df[y_col]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
X_train_s = ss.fit_transform(X_train)
#y_train_s = ss.fit_transform(y_train)
X_test_s = ss.transform(X_test)
X_train_s
# Out:
# array([[ 0.2504157 , -0.66120353,  0.61126033,  0.86655541,  0.58161093],
#        [-0.19761501, -1.47517503, -1.39998334, -2.87591702, -1.45416615],
#        [-1.40114849,  1.69717224,  0.94646761, -0.14924711,  0.49805787],
#        ...,
#        [-0.58415131, -0.31029436, -1.06477606,  0.40104591, -0.2021964 ],
#        [-1.1288161 ,  1.55833185,  0.61126033,  0.50102647,  0.77258937],
#        [-1.43628815, -0.42890343,  0.61126033, -0.31001585,  0.48943731]])

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()
LR.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(X_test_s)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2 = r2_score(y_test, y_pred)

f'R2:{r2}%'
# Out:
# 'R2:0.544638576722317%'
