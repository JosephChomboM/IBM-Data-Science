# %% [markdown]
# # Extraer los datos desde el CSV

# %%
#Ejercicio01: Establecer librerias a utilizar
import pandas as pd

# %%
#Ejercicio02: Definir las cabeceras del Dataset
headers = [
    'symboling',
    'normalized-losses',
    'make',
    'aspiration',
    'num-of-doors',
    'body-style',
    'drive-wheels',
    'engine-location',
    'wheel-base',
    'length',
    'width',
    'height',
    'curb-weight',
    'engine-type',
    'num-of-cylinders',
    'engine-size',
    'fuel-system',
    'bore',
    'stroke',
    'compression-ratio',
    'horsepower',
    'horsepower-binned',
    'peak-rpm',
    'city-mpg',
    'highway-mpg',
    'price',
    'city-L/100km',
    'diesel',
    'gas'
]

df = pd.read_csv('autos(in).csv', names= headers, sep=',')

# %%
len(headers)
# Out:
# 29

# %%
df.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3                 ?  alfa-romero        gas          std
# 1          3                 ?  alfa-romero        gas          std
# 2          1                 ?  alfa-romero        gas          std
# 3          2               164         audi        gas          std
# 4          2               164         audi        gas          std
#
#   body-style drive-wheels engine-location wheel-base  length  ...  \
# 0        two  convertible             rwd      front    88.6  ...
# 1        two  convertible             rwd      front    88.6  ...
# 2        two    hatchback             rwd      front    94.5  ...
# 3       four        sedan             fwd      front    99.8  ...
# 4       four        sedan             4wd      front    99.4  ...
#
#    compression-ratio  horsepower  horsepower-binned  peak-rpm city-mpg  \
# 0               2.68         9.0                111      5000       21
# ...

# %% [markdown]
# ## 1. Validación de los Datos

# %% [markdown]
# ### Descripción de las variables
#
# - 'symboling' : Nivel de riesgo del seguro , de menor riesgo (-3) a mayor riesgto (3)
# - "normalized-losses" : Es la perdida del pago promedio del seguro del auto por año y representa la perdida por año del auto. El valor oscila entre 65 a 256
# - 'make' : Marca
# - "aspiration" : Como el motor de combustión interno trabaja , puede ser estandar (std) o turbo
# - 'num-of-doors' : Número de puertas
# - "body-style" : Carroceria
# - 'drive-wheels' : Tracción de las ruedas
# - 'engine-location' : Localización del motor
# - 'wheel-base' : Distancia entre ejes
# - 'length' : Longitud
# - 'width' : Ancho
# - 'height': Alto
# - 'curb-weight' : Peso del auto con equipación completa
# - 'engine-type': Tipo de motor
# - 'num-of-cylinders' : Número de cilindros
# - 'engine-size' : Tamaño del motor
# - 'fuel-system' : Sistema de combustible
# - 'bore' : Diámetro
# - 'stroke' : Distancia recorrida por el pistón durante cada ciclo
# - 'compression-ratio': Ratio de comprensión
# - 'horsepower' : Caballos de potencia
# - 'horsepower-binned' : Caballos de potencia convertidos en una variable categórica
# - 'peak-rpm' : RPM pico
# - 'city-mpg' : consumo en la ciudad en millas por galon
# - 'highway-mpg' : consumo en autopista en millas por galon
# - 'price' : Precio
# - 'city-L/100km' :  consumo en la ciudad en litros por kilometro
# - 'diesel' : variable dummy para consumo por petróleo
# - 'gas': variable dummy para consumo por gasoina

# %%
#Ejercicio 01: Contar los datos del DataFrame

# %%
#Ejercicio 02: Mostrar los 5 primeros datos

# %%
#Ejercicio 03: Mostrar los 5 últimos datos
df.tail()
# Out:
#      symboling normalized-losses   make aspiration num-of-doors body-style  \
# 200         -1                95  volvo        gas          std       four
# 201         -1                95  volvo        gas        turbo       four
# 202         -1                95  volvo        gas          std       four
# 203         -1                95  volvo     diesel        turbo       four
# 204         -1                95  volvo        gas        turbo       four
#
#     drive-wheels engine-location wheel-base  length  ...  compression-ratio  \
# 200        sedan             rwd      front   109.1  ...               3.15
# 201        sedan             rwd      front   109.1  ...               3.15
# 202        sedan             rwd      front   109.1  ...               2.87
# 203        sedan             rwd      front   109.1  ...                3.4
# 204        sedan             rwd      front   109.1  ...               3.15
#
# ...

# %%
#Ejercicio 04: Ordenar los datos por columna

# %%
# Ejercicio05: Definir el formato de los datos perdidos
dato_perdido = '?'
nro_price_validate = df['price'].loc[df['price']] != dato_perdido.count()
nro_price_validate
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Ejercicio05: Definir el formato de los datos perdidos
#       2 dato_perdido = '?'
# ----> 3 nro_price_validate = df['price'].loc[df['price']] != dato_perdido.count()
#       4 nro_price_validate
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
# ...

# %%
# Ejercicio06: Definir valor perdido de Numpy
import numpy as np
type(np.nan)
# Out:
# float

# %%
# Ejercicio07: Reemplazar los valores perdidos por el valor de Numpy
df_replaced = df.replace("?", np.nan, inplace=False)
df_replaced.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3               NaN  alfa-romero        gas          std
# 1          3               NaN  alfa-romero        gas          std
# 2          1               NaN  alfa-romero        gas          std
# 3          2               164         audi        gas          std
# 4          2               164         audi        gas          std
#
#   body-style drive-wheels engine-location wheel-base  length  ...  \
# 0        two  convertible             rwd      front    88.6  ...
# 1        two  convertible             rwd      front    88.6  ...
# 2        two    hatchback             rwd      front    94.5  ...
# 3       four        sedan             fwd      front    99.8  ...
# 4       four        sedan             4wd      front    99.4  ...
#
#    compression-ratio  horsepower  horsepower-binned  peak-rpm city-mpg  \
# 0               2.68         9.0                111      5000       21
# ...

# %%
# Ejercicio08: Reemplazar los valores NaN por la media para el precio
avg_price = df_replaced['price'].astype('float').mean()
avg_price
df_replaced['price'].replace(np.nan, avg_price, inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4536\622744921.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_replaced['price'].replace(np.nan, avg_price, inplace=True)

# %%
#Ejercicio09: Ordenar los datos por columna de forma descendente
df_replaced.sort_values('make', ascending=False)
# Out:
#      symboling normalized-losses         make aspiration num-of-doors  \
# 204         -1                95        volvo        gas        turbo
# 199         -1                74        volvo        gas        turbo
# 194         -2               103        volvo        gas          std
# 195         -1                74        volvo        gas          std
# 196         -2               103        volvo        gas          std
# ..         ...               ...          ...        ...          ...
# 4            2               164         audi        gas          std
# 3            2               164         audi        gas          std
# 2            1               NaN  alfa-romero        gas          std
# 1            3               NaN  alfa-romero        gas          std
# 0            3               NaN  alfa-romero        gas          std
#
#     body-style drive-wheels engine-location wheel-base  length  ...  \
# ...

# %%
#Ejercicio10: ver los tipos de datos
df_replaced.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base            object
# length               float64
# width                float64
# height               float64
# curb-weight          float64
# engine-type            int64
# num-of-cylinders      object
# engine-size           object
# fuel-system            int64
# bore                  object
# stroke                object
# compression-ratio     object
# horsepower           float64
# horsepower-binned     object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# city-L/100km         float64
# diesel               float64
# gas                  float64
# dtype: object

# %%
# Ejercicio11: Corregir el formato del precio
df_replaced['price'] = df_replaced['price'].astype('float')
df_replaced['horsepower'] = df_replaced['horsepower'].astype('int64')

# %%
# Ejercicio12: Verificar la correccion del formato del precio

# %%
#Ejercicio 08: Describir la columna Precio
df_replaced['price'].describe()
# Out:
# count      205.000000
# mean     13207.129353
# std       7868.768212
# min       5118.000000
# 25%       7788.000000
# 50%      10595.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
#Ejercicio 09: Mostrar los elementos del dataFrame cuyos precios son mayores a 5000
df_replaced[df_replaced['price'] > 5000]
# Out:
#      symboling normalized-losses         make aspiration num-of-doors  \
# 0            3               NaN  alfa-romero        gas          std
# 1            3               NaN  alfa-romero        gas          std
# 2            1               NaN  alfa-romero        gas          std
# 3            2               164         audi        gas          std
# 4            2               164         audi        gas          std
# ..         ...               ...          ...        ...          ...
# 200         -1                95        volvo        gas          std
# 201         -1                95        volvo        gas        turbo
# 202         -1                95        volvo        gas          std
# 203         -1                95        volvo     diesel        turbo
# 204         -1                95        volvo        gas        turbo
#
#     body-style drive-wheels engine-location wheel-base  length  ...  \
# ...

# %%
#Ejercicio 10: Mostrar los elementos del dataFrame cuyos precios son mayores a 5000 y son marca audi
df_replaced[(df_replaced.price > 5000) & (df_replaced.make == 'audi')]
# Out:
#    symboling normalized-losses  make aspiration num-of-doors body-style  \
# 3          2               164  audi        gas          std       four
# 4          2               164  audi        gas          std       four
# 5          2               NaN  audi        gas          std        two
# 6          1               158  audi        gas          std       four
# 7          1               NaN  audi        gas          std       four
# 8          1               158  audi        gas        turbo       four
# 9          0               NaN  audi        gas        turbo        two
#
#   drive-wheels engine-location wheel-base  length  ...  compression-ratio  \
# 3        sedan             fwd      front    99.8  ...                3.4
# 4        sedan             4wd      front    99.4  ...                3.4
# 5        sedan             fwd      front    99.8  ...                3.4
# 6        sedan             fwd      front   105.8  ...                3.4
# ...

# %%
#Ejercicio 11: Establecer la influencia de tamaño del motor y la carroceria sobre el precio del auto

# %%
#Ejercicio 12: Graficar los resultados anteriores

# %%
#Ejercicio 13: Graficar la dispercion del tamaño del motor y el precio

# %%
#Ejercicio 14: Analizar la influencia de la ubicacion del motor en el precio

# %% [markdown]
# # Modelo Predictivo
# ### Regresión Lineal Simple

# %% [markdown]
# Obtencion de los coeficientes

# %%
# Los coeficientes

# %% [markdown]
# ### El modelo calculado tendra la siguiente forma :

# %% [markdown]
# $$ Y_{HAT} =  B_0 + B_1*X $$
